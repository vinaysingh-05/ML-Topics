# %%
from sklearn.datasets import load_diabetes
from sklearn.linear_model import LinearRegression,Ridge,Lasso,ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
X,y = load_diabetes(return_X_y=True)
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
# ElasticNet
reg = ElasticNet(alpha=0.005,l1_ratio=0.9)
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
print ("ElasticNet R2 Score:", r2_score(y_test,y_pred))
# Out:
# ElasticNet R2 Score: 0.4531474541554823

# %%
# Linear Regression
reg = LinearRegression()
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
print ("Linear Regression R2 Score:", r2_score(y_test,y_pred))
# Out:
# Linear Regression R2 Score: 0.439933866156897

# %%
# Ridge 
reg = Ridge(alpha=0.1)
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
print ("Ridge R2 Score:", r2_score(y_test,y_pred))
# Out:
# Ridge R2 Score: 0.45199494197195456

# %%
# Lasso
reg = Lasso(alpha=0.01)
reg.fit(X_train,y_train)
y_pred = reg.predict(X_test)
print ("Lasso R2 Score:", r2_score(y_test,y_pred))
# Out:
# Lasso R2 Score: 0.44111855963110613
