# %%
print("hello world")
# Out:
# hello world

# %%
import os
print("Current Working Directory:")
print(os.getcwd())

import os

os.chdir(r"C:\Users\vinay kumar\OneDrive\Documents\vinay\ML learning\simple-linear-regression")

print(os.getcwd())
print(os.listdir("data"))
# Out:
# Current Working Directory:
# c:\Users\vinay kumar\OneDrive\Documents\vinay\ML learning
# C:\Users\vinay kumar\OneDrive\Documents\vinay\ML learning\simple-linear-regression
# ['placement.csv']

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# derivation in simple linear regression my making fuction

# %%
class LR_Model:
    
    def __init__(self):
        self.m = None
        self.c = None

    def fit(self, X_train, Y_train):
        num = 0
        den = 0

        for i in range(X_train.shape[0]):
            num = num + (X_train[i] - X_train.mean()) * (Y_train[i] - Y_train.mean())
            den = den + (X_train[i] - X_train.mean()) * (X_train[i] - X_train.mean())

        self.m = num / den
        self.c = Y_train.mean() - self.m * X_train.mean()

    def predict(self, X_test):
        return self.m * X_test + self.c

# %%
df= pd.read_csv("data/placement.csv")

# %%
x = df["cgpa"].values
y = df["package"].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
lr= LR_Model()

# %%
lr.fit(X_train, Y_train)

# %%
print(lr.predict(X_test[0]))
# Out:
# 2.7803134765595168
